# %% [markdown]
# #Code

# %%
import sys, platform

# %%
import sys, platform

print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())

# Scientific core
import numpy as np, pandas as pd, matplotlib, sklearn
print("Numpy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)

# PyTorch stack
import torch, torchvision
print("PyTorch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA runtime:", torch.version.cuda)
print("cuDNN:", torch.backends.cudnn.version())

# Gradient boosting libs
try:
    import xgboost
    print("XGBoost:", xgboost.__version__)
except ImportError:
    print("XGBoost: not installed")

try:
    import lightgbm
    print("LightGBM:", lightgbm.__version__)
except ImportError:
    print("LightGBM: not installed")

# Transformers
try:
    import transformers
    print("Transformers:", transformers.__version__)
except ImportError:
    print("Transformers: not installed")

# TensorFlow (optional)
try:
    import tensorflow as tf
    print("TensorFlow:", tf.__version__)
except ImportError:
    print("TensorFlow: not installed")

# Optional video I/O libs
for pkg in ["decord", "av"]:
    try:
        mod = __import__(pkg)
        print(f"{pkg}:", mod.__version__)
    except:
        pass
# Out:
# Python: 3.12.12
# Platform: Linux-6.6.105+-x86_64-with-glibc2.35
# Numpy: 2.0.2
# Pandas: 2.2.2
# Matplotlib: 3.10.0
# Scikit-learn: 1.6.1
# PyTorch: 2.8.0+cu126
# Torchvision: 0.23.0+cu126
# CUDA available: True
# CUDA runtime: 12.6
# cuDNN: 91002
# XGBoost: 3.1.1
# LightGBM: 4.6.0
# Transformers: 4.57.1
# TensorFlow: 2.19.0

# %% [markdown]
# ### Clone repository

# %%
# !rm -r SpecklesAI

#if you are clonning a public version, use:
# !git clone https://github.com/natalyasegal/SpecklesAI.git
# Out:
# Cloning into 'SpecklesAI'...
# remote: Enumerating objects: 943, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 943 (delta 23), reused 0 (delta 0), pack-reused 891 (from 3)
# Receiving objects: 100% (943/943), 14.99 MiB | 8.97 MiB/s, done.
# Resolving deltas: 100% (491/491), done.

# %% [markdown]
# ### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### copy configuration files

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/code/config_files_pBCI/subjects_and_dates.yaml SpecklesAI/config/config_files/.
# !ls -l SpecklesAI/config/config_files/
# !cat SpecklesAI/config/config_files/ subjects_and_dates.yaml
# Out:
# total 16
# -rw-r--r-- 1 root root 182 Nov 16 11:24 per_subj_experiment_val_split.yaml
# -rw-r--r-- 1 root root 612 Nov 16 11:24 sample_gen_split.yaml
# -rw-r--r-- 1 root root 470 Nov 16 11:24 sample_test_sets.yaml
# -rw-r--r-- 1 root root 327 Nov 16 13:49 subjects_and_dates.yaml
# cat: SpecklesAI/config/config_files/: Is a directory
# cat: subjects_and_dates.yaml: No such file or directory

# %% [markdown]
# ## copy config.py (Broca)

# %%
# !cp SpecklesAI/config/config_BCI.py SpecklesAI/config/config.py

# %% [markdown]
# # Test forehead

# %% [markdown]
# ## code

# %%
import sys
sys.path.append('/content/SpecklesAI')   # add package root to Python path

#from utils.swap import swap_categories
from utils.swap import *

# %% [markdown]
# ## copy test sets

# %%
# !cp gdrive/MyDrive/__MSc_2023/code_and_data/test_prep_BCI_forehead/per_subj_tests/*.npy .
# !ls -l *.npy
# Out:
# -rw------- 1 root root 204800128 Nov 21 10:57 test_per_category_BCI_forehead___10.npy
# -rw------- 1 root root 122880128 Nov 21 10:57 test_per_category_BCI_forehead___1.npy
# -rw------- 1 root root 122880128 Nov 21 10:57 test_per_category_BCI_forehead___1_swapped.npy
# -rw------- 1 root root 122880128 Nov 21 10:57 test_per_category_BCI_forehead___2.npy
# -rw------- 1 root root 204800128 Nov 21 10:57 test_per_category_BCI_forehead___3.npy
# -rw------- 1 root root 122880128 Nov 21 10:57 test_per_category_BCI_forehead___4.npy
# -rw------- 1 root root 204800128 Nov 21 10:58 test_per_category_BCI_forehead___5_2.npy
# -rw------- 1 root root 122880128 Nov 21 10:58 test_per_category_BCI_forehead___5.npy
# -rw------- 1 root root 245760128 Nov 21 10:58 test_per_category_BCI_forehead___6.npy
# -rw------- 1 root root 204800128 Nov 21 10:58 test_per_category_BCI_forehead___7_2.npy
# -rw------- 1 root root 204800128 Nov 21 10:58 test_per_category_BCI_forehead___7.npy
# ...

# %% [markdown]
# ## subj 1 _with_corrected_set
# - swapping as order of lables for forehead set test_per_category_BCI_forehead___1.npy was [yes, no] and for per subj train/val/test sets it was [no, yes], the order changes came form set used in the code, it was fixed. No need to re-run per subj models as order is consistent per subj train/val/test sets

# %%
swapped = swap_file_with_tests("test_per_category_BCI_forehead___1.npy",
    "test_per_category_BCI_forehead___1_swapped.npy")
# !cp test_per_category_BCI_forehead___1_swapped.npy gdrive/MyDrive/__MSc_2023/code_and_data/test_prep_BCI_forehead/per_subj_tests/.
# Out:
# === Processing file: test_per_category_BCI_forehead___1.npy ===
# → Running correctness test BEFORE swap...
# ✓ Swap verified: sums, means, first/last values all match.
# → Running correctness test AFTER swap...
# ✓ Swap verified: sums, means, first/last values all match.
# ✓ Saved swapped array to: test_per_category_BCI_forehead___1_swapped.npy
# === Done ===

# %% [markdown]
# ### run

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_1/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___1_swapped.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c
# Out:
# 2025-11-21 11:00:21.472567: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763722821.496816    5732 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763722821.503905    5732 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763722821.521820    5732 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_1/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___1_swapped.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1_c_25
# Out:
# 2025-11-21 11:01:40.546100: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763722900.569241    6171 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763722900.576266    6171 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763722900.593787    6171 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 1

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_1/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___1.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_1
# Out:
# 2025-05-27 17:14:56.430771: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:14:56.449365: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366096.471278   58754 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366096.478903   58754 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## subj 2

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_2/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___2.npy --split_num 2 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2
# Out:
# cp: cannot stat 'gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_2/models': No such file or directory
# 2025-05-27 17:15:41.883300: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:15:41.901996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366141.923113   59205 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ### 25 - no beep

# %%
#!ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/
#per_subj_split__2_no_beep
#per_subj_split_2_take2

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split__2_no_beep/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25no_beep
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25no_beep/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25no_beep/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25no_beep/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25no_beep
# Out:
# 2025-11-19 13:09:03.402588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763557743.417023   17033 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763557743.421186   17033 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763557743.432623   17033 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ### 25 take 2

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_2_take2/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25_take2
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25_take2/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25_take2/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25_take2/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_2_25_take2
# Out:
# 2025-11-19 13:10:01.521617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763557801.535594   17397 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763557801.539635   17397 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763557801.550306   17397 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 3

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_3/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___3.npy --split_num 2 #patch giving meaningless split number here
# Out:
# 2025-06-05 21:41:28.267306: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-05 21:41:28.285994: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749159688.306716   11479 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749159688.313110   11479 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_3/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___3.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_3_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_3_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_3_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_3_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_3_25
# Out:
# 2025-11-19 13:15:14.171955: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558114.186546   19007 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558114.190720   19007 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558114.201762   19007 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 4

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_4/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___4.npy --split_num 4 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4
# Out:
# 2025-05-27 17:16:23.763431: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:16:23.782418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366183.803591   59629 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366183.810322   59629 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_4/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___4.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_4_25
# Out:
# 2025-11-19 13:18:52.528510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558332.542359   20016 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558332.546554   20016 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558332.557658   20016 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 5

# %%
# !cp	gdrive/MyDrive/__MSc_2023/code_and_data/test_prep_BCI_forehead/per_subj_tests/test_per_category_BCI_forehead___5_2.npy .
# !ls
# Out:
# gdrive
# sample_data
# SpecklesAI
# test_per_category_BCI_forehead___10.npy
# test_per_category_BCI_forehead___1.npy
# test_per_category_BCI_forehead___1_swapped.npy
# test_per_category_BCI_forehead___2.npy
# test_per_category_BCI_forehead___3.npy
# test_per_category_BCI_forehead___4.npy
# test_per_category_BCI_forehead___5_2.npy
# test_per_category_BCI_forehead___5.npy
# test_per_category_BCI_forehead___6.npy
# test_per_category_BCI_forehead___7_2.npy
# test_per_category_BCI_forehead___7.npy
# test_per_category_BCI_forehead___8.npy
# test_per_category_BCI_forehead___8_swapped.npy
# test_per_category_BCI_forehead___9.npy

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_5/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___5_2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2
# Out:
# 2025-06-10 13:49:46.440276: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-10 13:49:46.458973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749563386.479724   20341 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749563386.486192   20341 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_5/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___5_2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5_2_25
# Out:
# 2025-11-19 13:22:04.918792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558524.944003   20917 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558524.951088   20917 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558524.971500   20917 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 5 - old

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_5/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___5.npy --split_num 5 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_5
# Out:
# 2025-05-27 17:17:01.339699: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:17:01.357858: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366221.378747   60042 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366221.385350   60042 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## subj 6

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_6/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___6.npy --split_num 6 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6
# Out:
# 2025-05-27 17:17:33.637753: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:17:33.656528: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366253.677808   60427 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366253.684549   60427 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_6/models .


# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___6.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_6_25
# Out:
# 2025-11-19 13:24:14.641959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558654.656433   21565 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558654.660528   21565 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558654.671441   21565 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 7

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_7/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___7_2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2
# Out:
# 2025-06-05 21:45:53.358288: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-05 21:45:53.378117: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749159953.399239   13362 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749159953.405711   13362 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_7/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___7_2.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7_2_25
# Out:
# 2025-11-19 13:25:37.630429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558737.644497   22028 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558737.648606   22028 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558737.659789   22028 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 7 - old

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_7/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___7.npy --split_num 7 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_7
# Out:
# 2025-05-27 17:17:57.710798: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:17:57.728923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366277.749897   60779 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366277.756328   60779 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## subj 8 - corrected (see explanation above)

# %%
swapped = swap_file_with_tests("test_per_category_BCI_forehead___8.npy",
    "test_per_category_BCI_forehead___8_swapped.npy")
# !cp test_per_category_BCI_forehead___8_swapped.npy gdrive/MyDrive/__MSc_2023/code_and_data/test_prep_BCI_forehead/per_subj_tests/.
# Out:
# === Processing file: test_per_category_BCI_forehead___8.npy ===
# → Running correctness test BEFORE swap...
# ✓ Swap verified: sums, means, first/last values all match.
# → Running correctness test AFTER swap...
# ✓ Swap verified: sums, means, first/last values all match.
# ✓ Saved swapped array to: test_per_category_BCI_forehead___8_swapped.npy
# === Done ===

# %% [markdown]
# #### run

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_8/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___8_swapped.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c
# Out:
# 2025-11-19 12:49:54.835511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763556594.850147   11962 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763556594.854283   11962 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763556594.865329   11962 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_8/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___8_swapped.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8_c_25
# Out:
# 2025-11-19 13:39:06.145797: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763559546.159834   25650 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763559546.164045   25650 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763559546.175423   25650 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 8

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_8/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___8.npy --split_num 8 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_8
# Out:
# 2025-05-27 17:18:26.056792: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 17:18:26.075760: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748366306.096669   61146 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748366306.103502   61146 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## subj 9

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_9/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___9.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9
# Out:
# 2025-05-27 20:55:21.142624: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 20:55:21.161530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748379321.182911   11461 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748379321.189323   11461 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_9/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___9.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_9_25
# Out:
# 2025-11-19 13:28:36.114800: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763558916.130103   22863 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763558916.134885   22863 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763558916.146267   22863 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## subj 10

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_10/models .

#50 as there is a word every 2 sec in version of data with beep
# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 50 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___10.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10
# Out:
# 2025-06-10 13:11:28.286193: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-10 13:11:28.304914: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749561088.325968   10469 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749561088.332412   10469 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 25

# %%
# !cp -r gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_models_per_subj/per_subj_split_10/models .

# !python -u SpecklesAI/inference_and_eval.py --use_per_subj_config --num_of_chunks_to_aggregate 25 --read_stored_dataset  --test_set_per_category_file test_per_category_BCI_forehead___10.npy --split_num 1 #patch giving meaningless split number here

# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10_25
# !mv models gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10_25/.
# !mv *.png gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10_25/.
# !mv *.csv gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10_25/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/pBCI_control__test_forehead_per_subj/per_subj_10_25
# Out:
# 2025-11-19 13:32:35.244076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763559155.258578   23952 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763559155.262799   23952 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763559155.273830   23952 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Take a look

# %%
# !ls -l
# Out:
# total 600392
# -rw-r--r--  1 root root     22764 Apr  2 06:40 accuracy.png
# drwxr-xr-x  2 root root      4096 Apr  2 06:50 BCI_Zeev_310325_morning
# -rw-r--r--  1 root root     17340 Apr  2 06:40 confusion_matrix_agg.png
# -rw-r--r--  1 root root     20128 Apr  2 06:40 confusion_matrix.png
# drwxr-xr-x  4 root root      4096 Apr  2 06:56 data
# drwxr-xr-x  4 root root      4096 Apr  2 06:55 exp3
# drwx------  6 root root      4096 Apr  2 06:33 gdrive
# -rw-r--r--  1 root root     21163 Apr  2 06:40 loss.png
# drwxr-xr-x  2 root root      4096 Apr  2 06:36 models
# -rw-r--r--  1 root root     36648 Apr  2 06:40 roc_curve_agg.png
# -rw-r--r--  1 root root     41812 Apr  2 06:40 roc_curve.png
# drwxr-xr-x  1 root root      4096 Mar 31 13:41 sample_data
# drwxr-xr-x 10 root root      4096 Apr  2 06:35 SpecklesAI
# -rw-r--r--  1 root root     72971 Apr  2 06:36 speckles_sample.png
# -rw-r--r--  1 root root      1626 Apr  2 06:40 Subj_experiment_model_accuracy.csv
# ...

# %%
# !mv test_per_category__per_subj__1.npy test_per_category__per_subj__5.npy
# !mv  train_set__per_subj__1.npy train_set__per_subj__5.npy
# !mv validation_set__per_subj__1.npy validation_set__per_subj__5.npy
# !ls -l
# Out:
# total 360088
# drwxr-xr-x 2 root root      4096 Apr  1 21:48 BCI_Zeev_310325_midday
# drwxr-xr-x 2 root root      4096 Apr  1 21:48 BCI_Zeev_310325_morning
# drwxr-xr-x 4 root root      4096 Apr  1 21:49 data
# drwxr-xr-x 4 root root      4096 Apr  1 21:48 exp3
# drwx------ 6 root root      4096 Apr  1 21:41 gdrive
# drwxr-xr-x 1 root root      4096 Mar 31 13:41 sample_data
# drwxr-xr-x 9 root root      4096 Apr  1 21:42 SpecklesAI
# -rw-r--r-- 1 root root 122880128 Apr  1 21:49 test_per_category__per_subj__5.npy
# -rw-r--r-- 1 root root 225324256 Apr  1 21:49 train_set__per_subj__5.npy
# -rw-r--r-- 1 root root  20484256 Apr  1 21:49 validation_set__per_subj__5.npy

# %%
# !ls  -l gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits/
# Out:
# total 1200171
# -rw------- 1 root root  40960128 Mar 30 20:49 test_per_category__per_subj___1_no_beep.npy
# -rw------- 1 root root 122880128 Mar 30 20:50 test_per_category__per_subj__1.npy
# -rw------- 1 root root  40960128 Nov 14 10:02 test_per_category__per_subj__2.npy
# -rw------- 1 root root  40960128 Nov 14 10:02 test_per_category__per_subj__3.npy
# -rw------- 1 root root 122880128 Mar 16 21:19 test_per_category__per_subj__4.npy
# -rw------- 1 root root  61452256 Mar 30 20:48 train_set__per_subj___1_no_beep.npy
# -rw------- 1 root root 389196256 Mar 30 20:50 train_set__per_subj__1.npy
# -rw------- 1 root root  61452256 Nov 14 10:02 train_set__per_subj__2.npy
# -rw------- 1 root root  61452256 Nov 14 10:02 train_set__per_subj__3.npy
# -rw------- 1 root root 184356256 Mar 16 21:19 train_set__per_subj__4.npy
# -rw------- 1 root root  20484256 Mar 30 20:48 validation_set__per_subj___1_no_beep.npy
# -rw------- 1 root root  20484256 Mar 30 20:50 validation_set__per_subj__1.npy
# ...

# %%
# !cp  *__5.npy gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits/.
# !ls  gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits/
# Out:
# test_per_category__per_subj___1_no_beep.npy  train_set__per_subj___3_no_beep.npy
# test_per_category__per_subj__1.npy	     train_set__per_subj__3.npy
# test_per_category__per_subj___2_no_beep.npy  train_set__per_subj__4.npy
# test_per_category__per_subj__2.npy	     train_set__per_subj__5.npy
# test_per_category__per_subj___3_no_beep.npy  validation_set__per_subj___1_no_beep.npy
# test_per_category__per_subj__3.npy	     validation_set__per_subj__1.npy
# test_per_category__per_subj__4.npy	     validation_set__per_subj___2_no_beep.npy
# test_per_category__per_subj__5.npy	     validation_set__per_subj__2.npy
# train_set__per_subj___1_no_beep.npy	     validation_set__per_subj___3_no_beep.npy
# train_set__per_subj__1.npy		     validation_set__per_subj__3.npy
# train_set__per_subj___2_no_beep.npy	     validation_set__per_subj__4.npy
# train_set__per_subj__2.npy		     validation_set__per_subj__5.npy

# %%
# !ls -l
# Out:
# total 440084
# drwxr-xr-x 2 root root      4096 Mar 30 22:06 BCI_Natalya_240325_midday
# drwxr-xr-x 2 root root      4096 Mar 30 22:06 BCI_Natalya_240325_morning
# drwxr-xr-x 4 root root      4096 Mar 30 22:10 data
# drwxr-xr-x 4 root root      4096 Mar 30 22:06 exp3
# drwx------ 6 root root      4096 Mar 30 21:40 gdrive
# drwxr-xr-x 1 root root      4096 Mar 24 13:34 sample_data
# drwxr-xr-x 9 root root      4096 Mar 30 21:23 SpecklesAI
# -rw-r--r-- 1 root root 204800128 Mar 30 22:11 test_per_category__per_subj__3.npy
# -rw-r--r-- 1 root root 225324256 Mar 30 22:11 train_set__per_subj__3.npy
# -rw-r--r-- 1 root root  20484256 Mar 30 22:11 validation_set__per_subj__3.npy

# %% [markdown]
# ##Save

# %%
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI
# !mkdir gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits
# !mv *.npy	gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits/.
# !ls -l gdrive/MyDrive/__MSc_2023/code_and_data/data_exp3_prep_BCI/per_subj_splits
